# %% [markdown]
# # Replication of Table 2

# %% [markdown]
# ## Base Model

# %%
import matplotlib.pyplot as plt
from src.experiments import Base_Table2, ARIMA_Tabel2

# %%
pred_base, true_base = Base_Table2()
# Out:
# Test Set Metrics:
# RMSE : 1.41, MAE : 0.89, MAPE : 1.81(x10^-2%)

# %%
plt.plot(pred_base[-100:], label="Predictions")
plt.plot(true_base[-100:], label="True values")
plt.legend()

# %% [markdown]
# ## ARIMA

# %%
pred, true = ARIMA_Tabel2()
# Out:
# 100%|██████████| 2729/2729 [12:35<00:00,  3.61it/s]
# Test Set Metrics:
# RMSE : 1.41, MAE : 0.89, MAPE : 1.81(x10^-2%)

# %%
plt.plot(pred[-100:], label="Predictions")
plt.plot(true[-100:], label="True values")
plt.legend()
